# %%
from gym_interface import RobotEnv
from policy import EigenPolicy
from utils import notebook_plot

env = RobotEnv(simulator="none")
observation, info = env.reset()

model_path = "Diffusion_Policy_epoch100.pkl"
policy = EigenPolicy(model_path, arch="diffusion", device="cpu")
# Out:
# [WARNING] [13:06:12.151699] - No global configuration provided. Using default system configuration.
# [INFO] [13:06:12.155264] - Service: Successfully registered '__DEFAULT_SERVICE/GetInfo/SO-101 Environment_7caa9b70-fdea-4b80-bf86-77078122df49' with registry.
# [INFO] [13:06:12.157391] - Service: Successfully registered '__DEFAULT_SERVICE/SuspendNode/SO-101 Environment_7caa9b70-fdea-4b80-bf86-77078122df49' with registry.
# [INFO] [13:06:12.160452] - Service: Successfully registered '__DEFAULT_SERVICE/RestartNode/SO-101 Environment_7caa9b70-fdea-4b80-bf86-77078122df49' with registry.
# [ERROR] [13:06:12.161530] - Couldn't load config for other 'SO-101 Environment'
# [WARNING] [13:06:12.163471] - No configuration file provided. Using default configuration.
# [OK] [13:06:12.165211] - setup publisher SO101/joint_group_command[joint_group_command_t]
# [OK] [13:06:12.167030] - subscribed to Camera/rgbd[rgbd_t]
# [WARNING] [13:06:12.171646] - Observation space is getting checked
# None

# %%
while not policy.is_finished():
    action = policy(observation)
    observation, reward, terminated, truncated, info = env.step(action)
    notebook_plot(observation)
